# %% [markdown]
# # Results

# %%
import sys
sys.path.insert(0, '..')
from utils import plot_stroke

# %% [markdown]
# This is what you should modify:

# %%
from models.lstm_model import generate_unconditionally, generate_conditionally, recognize_stroke

# %% [markdown]
# Please, don't modify anything below.
#
# ### Unconditional generation:

# %%
stroke = generate_unconditionally()
plot_stroke(stroke)
# Out:
# INFO:tensorflow:Restoring parameters from ../data/checkpoints/model-prediction.ckpt
#   0%|                                                                                          | 0/699 [00:00<?, ?it/s]..\models\lstm_model.py:353: RuntimeWarning: covariance is not positive-semidefinite.
#   x = np.random.multivariate_normal(mean, covariance_matrix, 1)
# 100%|███████████████████████████████████████████████████████████████████████████████| 699/699 [00:02<00:00, 298.70it/s]

# %% [markdown]
# ### Conditional generation:

# %%
stroke = generate_conditionally(text='welcome to lyrebird')
plot_stroke(stroke)

# %% [markdown]
# ### Handwriting recognition:

# %%
text = recognize_stroke(stroke)
print (text)
# Out:
# welcome to lyrebird
